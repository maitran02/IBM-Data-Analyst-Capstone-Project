# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# * Extract information from a given web site
# * Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# Your code here
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
data  = requests.get(url).text 
data
# Out:
# '<!doctype html>\n<html lang="en">\n<head>\n<title>\nSalary survey results of programming languages\n</title>\n<style>\ntable, th, td {\n  border: 1px solid black;\n}\n</style>\n</head>\n\n<body>\n<hr />\n<h2>Popular Programming Languages</h2>\n<hr />\n<p>Finding out which is the best language is a tough task. A programming language is created to solve a specific problem. A language which is good for task A may not be able to properly handle task B. Comparing programming language is never easy. What we can do, however, is find which is popular in the industry.</p>\n<p>There are many ways to find the popularity of a programming languages. Counting the number of google searchs for each language is a simple way to find the popularity. GitHub and StackOverflow also can give some good pointers.</p>\n<p>Salary surveys are a way to find out the programmings languages that are most in demand in the industry. Below table is the result of one such survey. When using any survey keep in mind tha
# ...

# %% [markdown]
# Create a soup object

# %%
soup = BeautifulSoup(data, 'html5lib')
soup.head()
# Out:
# [<title>
#  Salary survey results of programming languages
#  </title>,
#  <style>
#  table, th, td {
#    border: 1px solid black;
#  }
#  </style>]

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
table = soup.find('table')
lang_name = []
annual_avg_sal = []

for row in table.find_all('tr'):
    cols = row.find_all('td')
    lang_name.append(cols[1].getText())
    annual_avg_sal.append(cols[3].getText())

lang_name
# Out:
# ['Language',
#  'Python',
#  'Java',
#  'R',
#  'Javascript',
#  'Swift',
#  'C++',
#  'C#',
#  'PHP',
#  'SQL',
#  'Go']

# %%
# df_lang_sal = pd.DataFrame([])
lang_name = []
avg_annual_sal = []

table = soup.find('table')

for row in table.find_all('tr'):
    cols = row.find_all('td')
    lang_name.append(cols[1].getText())
    avg_annual_sal.append(cols[3].getText())

header_lang = lang_name.pop(0)
header_sal = avg_annual_sal.pop(0)
df_lang_sal = pd.DataFrame({header_lang: lang_name, header_sal: avg_annual_sal})

# Save the scrapped data into a file named *popular-languages.csv*
df_lang_sal.to_csv('popular-languages.csv', index=False)
print(pd.read_csv('popular-languages.csv'))
# Out:
#      Language Average Annual Salary
# 0      Python              $114,383
# 1        Java              $101,013
# 2           R               $92,037
# 3  Javascript              $110,981
# 4       Swift              $130,801
# 5         C++              $113,865
# 6          C#               $88,726
# 7         PHP               $84,727
# 8         SQL               $84,793
# 9          Go               $94,082

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |

# %% [markdown]
#  Copyright &copy; 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01).
